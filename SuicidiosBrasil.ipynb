# %% [markdown]
# <a href="https://colab.research.google.com/github/andresantos258/Google_colab/blob/main/SuicidiosBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# %%
# !python -m pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 30.9 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
dataset = "https://raw.githubusercontent.com/andresantos258/Google_colab/main/encoded-suicidio.csv"

# %%
suicidios_br = pd.read_csv(dataset)

# %%
suicidios_br.head(5)
# Out:
#          UF     1996     1997     1998     1999     2000     2001     2002  \
# 0  Rondônia    1.068    1.050    1.221    1.104    1.221    1.358    1.490
# 1      Acre  310.000  342.000  331.000  246.000  302.000  321.000  407.000
# 2  Amazonas    1.199    1.240    1.299    1.233    1.352    1.255    1.349
# 3   Roraima  268.000  273.000  334.000  397.000  348.000  328.000  344.000
# 4      Pará    2.150    2.363    2.494    2.322    2.233    2.632    3.047
#
#       2003     2004  ...     2013     2014     2015     2016     2017  \
# 0    1.410    1.414  ...    1.406    1.479    1.508    1.571    1.458
# 1  360.000  287.000  ...  522.000  550.000  507.000  655.000  820.000
# 2    1.389    1.476  ...    2.596    2.721    2.989    2.821    3.005
# 3  305.000  342.000  ...  506.000  435.000  536.000  474.000  590.000
# 4    3.223    3.367  ...    6.487    6.657    6.850    7.432    7.714
#
#       2018     2019    total  latitude  longitude
# ...

# %%
dicionario = suicidios_br.to_dict('records')

# %%
dicionario
# Out:
# [{'UF': 'Rondônia',
#   '1996': 1.068,
#   '1997': 1.05,
#   '1998': 1.221,
#   '1999': 1.104,
#   '2000': 1.221,
#   '2001': 1.358,
#   '2002': 1.49,
#   '2003': 1.41,
#   '2004': 1.414,
#   '2005': 1.408,
#   '2006': 1.377,
#   '2007': 1.112,
#   '2008': 1.306,
#   '2009': 1.436,
#   '2010': 1.528,
#   '2011': 1.397,
#   '2012': 1.566,
#   '2013': 1.406,
#   '2014': 1.479,
#   '2015': 1.508,
#   '2016': 1.571,
#   '2017': 1.458,
#   '2018': 1.29,
#   '2019': 1.314,
#   'total': 32.492,
#   'latitude': -8.7619,
#   'longitude': -63.9039},
#  {'UF': 'Acre',
#   '1996': 310.0,
#   '1997': 342.0,
#   '1998': 331.0,
#   '1999': 246.0,
#   '2000': 302.0,
#   '2001': 321.0,
#   '2002': 407.0,
#   '2003': 360.0,
#   '2004': 287.0,
#   '2005': 337.0,
#   '2006': 375.0,
#   '2007': 357.0,
#   '2008': 355.0,
#   '2009': 387.0,
#   '2010': 439.0,
#   '2011': 488.0,
#   '2012': 531.0,
#   '2013': 522.0,
#   '2014': 550.0,
#   '2015': 507.0,
#   '2016': 655.0,
#   '2017': 820.0,
# ...

# %%
cliente = MongoClient("mongodb+srv://andresantos2227:QWJppo8l68jpq43v@clustersuicidios.w9yxmxs.mongodb.net/?retryWrites=true&w=majority")

# %%
db = cliente.get_database('brasil')

# %%
db.suicidios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('65554aedbcc5d0abc8e3d8b0'), ObjectId('65554aedbcc5d0abc8e3d8b1'), ObjectId('65554aedbcc5d0abc8e3d8b2'), ObjectId('65554aedbcc5d0abc8e3d8b3'), ObjectId('65554aedbcc5d0abc8e3d8b4'), ObjectId('65554aedbcc5d0abc8e3d8b5'), ObjectId('65554aedbcc5d0abc8e3d8b6'), ObjectId('65554aedbcc5d0abc8e3d8b7'), ObjectId('65554aedbcc5d0abc8e3d8b8'), ObjectId('65554aedbcc5d0abc8e3d8b9'), ObjectId('65554aedbcc5d0abc8e3d8ba'), ObjectId('65554aedbcc5d0abc8e3d8bb'), ObjectId('65554aedbcc5d0abc8e3d8bc'), ObjectId('65554aedbcc5d0abc8e3d8bd'), ObjectId('65554aedbcc5d0abc8e3d8be'), ObjectId('65554aedbcc5d0abc8e3d8bf'), ObjectId('65554aedbcc5d0abc8e3d8c0'), ObjectId('65554aedbcc5d0abc8e3d8c1'), ObjectId('65554aedbcc5d0abc8e3d8c2'), ObjectId('65554aedbcc5d0abc8e3d8c3'), ObjectId('65554aedbcc5d0abc8e3d8c4'), ObjectId('65554aedbcc5d0abc8e3d8c5'), ObjectId('65554aedbcc5d0abc8e3d8c6'), ObjectId('65554aedbcc5d0abc8e3d8c7'), ObjectId('65554aedbcc5d0abc8e3d8c8'), ObjectId('65554aedbcc5d0abc8e3
# ...

# %%
suicidios = db.suicidios

# %%
suicidios
# Out:
# Collection(Database(MongoClient(host=['ac-hejbjag-shard-00-02.w9yxmxs.mongodb.net:27017', 'ac-hejbjag-shard-00-00.w9yxmxs.mongodb.net:27017', 'ac-hejbjag-shard-00-01.w9yxmxs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-ssukz0-shard-0', tls=True), 'brasil'), 'suicidios')

# %%
list(suicidios.find())
# Out:
# [{'_id': ObjectId('65554aedbcc5d0abc8e3d8b0'),
#   'UF': 'Rondônia',
#   '1996': 1.068,
#   '1997': 1.05,
#   '1998': 1.221,
#   '1999': 1.104,
#   '2000': 1.221,
#   '2001': 1.358,
#   '2002': 1.49,
#   '2003': 1.41,
#   '2004': 1.414,
#   '2005': 1.408,
#   '2006': 1.377,
#   '2007': 1.112,
#   '2008': 1.306,
#   '2009': 1.436,
#   '2010': 1.528,
#   '2011': 1.397,
#   '2012': 1.566,
#   '2013': 1.406,
#   '2014': 1.479,
#   '2015': 1.508,
#   '2016': 1.571,
#   '2017': 1.458,
#   '2018': 1.29,
#   '2019': 1.314,
#   'total': 32.492,
#   'latitude': -8.7619,
#   'longitude': -63.9039},
#  {'_id': ObjectId('65554aedbcc5d0abc8e3d8b1'),
#   'UF': 'Acre',
#   '1996': 310.0,
#   '1997': 342.0,
#   '1998': 331.0,
#   '1999': 246.0,
#   '2000': 302.0,
#   '2001': 321.0,
#   '2002': 407.0,
#   '2003': 360.0,
#   '2004': 287.0,
#   '2005': 337.0,
#   '2006': 375.0,
#   '2007': 357.0,
#   '2008': 355.0,
#   '2009': 387.0,
#   '2010': 439.0,
#   '2011': 488.0,
#   '2012': 531.0,
# ...

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(suicidios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id          65554aedbcc5d0abc8e3d8b0
# UF                           Rondônia
# 1996                            1.068
# 1997                             1.05
# 1998                            1.221
# 1999                            1.104
# 2000                            1.221
# 2001                            1.358
# 2002                             1.49
# 2003                             1.41
# 2004                            1.414
# 2005                            1.408
# 2006                            1.377
# 2007                            1.112
# 2008                            1.306
# 2009                            1.436
# 2010                            1.528
# 2011                            1.397
# 2012                            1.566
# 2013                            1.406
# 2014                            1.479
# 2015                            1.508
# 2016                            1.571
# 2017                            1.458
# 2018                             1.29
# ...

# %%
locationmap = folium.Map(location=[ center_lat , center_lon ] , zoom_start=5, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 27

# %%
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  description = 'Estado: ' +str(df_convertido.iloc[i]['UF']) + '<br> Total de suicídios <br> de 1996 a 2019: ' + str(df_convertido.iloc[i]['total'])
  folium.Marker( [lat, lng],
                popup = description,
                 icon = folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
